# %% [markdown]
# # Data Incubator: Project Proposal
# ### Preliminary Analysis, and Proof of Signal
#
# #### Denis Vrdoljak

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
# %matplotlib inline

# %%
#os.getcwd()

# %%
testperms = pd.read_csv('fptest-counts-2perms.txt', delimiter=' ', header=None, names=('count','word-pairs'))
testbigrams = pd.read_csv('fptest-counts-bigrams.txt', delimiter=' ', header=None, names=('count','bigrams'))

# %%
#testperms.head()
#testbigrams.head()

# %%
fullperms = pd.read_csv('DS-counts-2perms.txt', delimiter=' ', header=None, names=('count','word-pairs'))
fullbigrams = pd.read_csv('DS-counts-bigrams.txt', delimiter=' ', header=None, names=('count','bigrams'))

# %%
#fullperms .head()
#fullbigrams.head()

# %% [markdown]
# ## Bigrams and (same-line) word-pairs
# ### Data: 300 Job Postings (test/dev set)

# %%
testperms.head(15).plot(kind='bar',x='word-pairs')
testbigrams.head(15).plot(kind='bar',x='bigrams').invert_yaxis()

# %% [markdown]
# ## Bigrams and (same-line) word-pairs
# ### Data: 20k Job Postings

# %%
fullperms.head(15).plot(kind='bar',x='word-pairs')
fullbigrams.head(15).plot(kind='bar',x='bigrams').invert_yaxis()
